# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
m = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/mushrooms.csv')
m
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
m.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
m['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
m['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='class', data = m)

# %%
m.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
#No null values. Just for another view, Heatmap is used

import seaborn as sns

sns.heatmap(m.isnull())

# %%
m.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [raw]
# To convert rest of the columns from object to numerical, Label Encoder is used.

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
for column in m.columns:
    m[column] = le.fit_transform(m[column])

# %%
m.dtypes
# Out:
# class                       int32
# cap-shape                   int32
# cap-surface                 int32
# cap-color                   int32
# bruises                     int32
# odor                        int32
# gill-attachment             int32
# gill-spacing                int32
# gill-size                   int32
# gill-color                  int32
# stalk-shape                 int32
# stalk-root                  int32
# stalk-surface-above-ring    int32
# stalk-surface-below-ring    int32
# stalk-color-above-ring      int32
# stalk-color-below-ring      int32
# veil-type                   int32
# veil-color                  int32
# ring-number                 int32
# ring-type                   int32
# spore-print-color           int32
# population                  int32
# habitat                     int32
# dtype: object

# %%
m
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %% [raw]
# column 'veil-type' seems to have no helping data.

# %%
m.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
m['veil-type'].unique()
# Out:
# array([0])

# %%
#The column 'veil-type' only has 0 in it and do not contribute anything for the output. It can be ommited.

m_new = m.drop(['veil-type'], axis = 1)

# %%
m_new
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
m_new.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %% [raw]
# 'gill-color', 'bruises' seems to be in reverse trend with 'Class'

# %%
sns.heatmap?

# %%
plt.figure(figsize=(20,15))
sns.heatmap(m_new.corr(), annot = True)

# %%
x = m_new.iloc[:,1:]

# %%
y = m_new.iloc[:,0]

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int32

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=.55,random_state=60)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

model1 = [LogisticRegression(), GaussianNB(), KNeighborsClassifier(), DecisionTreeClassifier(), RandomForestClassifier()]

# %%
for m in model1:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    pred = m.predict(x_test)
    print(accuracy_score(y_test,pred))
# Out:
# 0.9474155292011636
# 0.920340120832401
# 0.9977623629447304
# 1.0
# 1.0

# %%
from sklearn.svm import SVC

def svmkernel(ker):
    svc = SVC(kernel = ker)
    svc.fit(x_train, y_train)
    pred1 = svc.predict(x_test)
    print(accuracy_score(y_test,pred1))

# %%
svmkernel('rbf')
# Out:
# 0.9879167599015439

# %%
svmkernel('poly')
# Out:
# 0.9959722533005146

# %%
svmkernel('linear')
# Out:
# 0.963526515999105

# %%
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

model = [LogisticRegression(), GaussianNB(), KNeighborsClassifier(), DecisionTreeClassifier(), SVC(), RandomForestClassifier()]

for m in model:
    scores = cross_val_score(m, x, y, cv=5)
    print(scores)
    print(scores.mean(), scores.std(), '\n')

print('LogisticRegression,', 'GaussianNB,', 'KNeighborsClassifier,', 'DecisionTreeClassifier,', 'SVC,', 'RandomForestClassifier.')
# Out:
# [0.63015385 0.984      0.87569231 0.99815385 0.71366995]
# 0.8403339901477832 0.1462988118645495
#
# [0.72923077 0.96123077 0.79261538 0.65230769 0.49445813]
# 0.7259685486926866 0.15415819916568615
#
# [0.84492308 0.99753846 0.93169231 1.         0.63362069]
# 0.8815549071618036 0.13624129405764812
#
# [0.88184615 1.         0.99507692 1.         0.74876847]
# 0.9251383099658963 0.09907621821537838
#
# [0.816      0.99569231 0.89907692 1.         0.49938424]
# 0.8420306934444864 0.18433917506164213
#
# [0.84246154 1.         0.99876923 1.         0.63362069]
# 0.8949702917771883 0.1441509505058579
#
# LogisticRegression, GaussianNB, KNeighborsClassifier, DecisionTreeClassifier, SVC, RandomForestClassifier.

# %% [raw]
# As we can see, dtc model seems to be working well.
#
# MODEL         ACCURACY                CROSS-VAL                Difference
#
# dtc             1.0               0.9275962106858658       0.07240378931413416
#
# svm             1.0               0.8420306934444864       0.15796930655551356
#
# rt              1.0               0.8949702917771883       0.10502970822281166
#
# knn             0.99              0.8815549071618036       0.10844509283819637
#
# lr              0.95              0.8403339901477832       0.10708153905338036
#
# GNB             0.92              0.7259685486926866       0.19437157213971445

# %% [markdown]
# # dtc difference value is less, thus dtc model is preffered for better distinction between edible and poisonous.
